# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# This Notebook is used to build the code to scrape the following Wikipedia page,

# %% [markdown]
# > https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe.

# %% [markdown]
# ## *Getting wikipedia data*

# %% [markdown]
# #### Let's get started!
#
# First, we have to import the libraries:

# %%
#import libraries
#!conda install -c conda-forge folium

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json # library to handle JSON files
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium

# %% [markdown]
# Now, we scrap the wikipedia table by using BeautifulSoup and pandas libraries.

# %%
wiki = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(wiki,'lxml')
table = soup.find("table",{"class":"wikitable sortable"})

# %%
#table #to see its content

# %% [markdown]
# #### We can now create a data frame by looping through BeautifulSoup Table.
#
# I recommend that you see the contents of the table to better understand this process.

# %%
#Create data frame

columns=['Postal Code','Borough','Neighborhood']
df=pd.DataFrame(columns=columns)
p=[]
b=[]
n=[]

for row in table.findAll("tr"):
    cells = row.findAll("td")
    if len(cells) == 3:
        p.append(cells[0].find(text=True).lstrip('\n').strip())
        b.append(cells[1].find(text=True).lstrip('\n').strip())
        n.append(cells[2].find(text=True).lstrip('\n').strip())

df['Postal Code']=p
df['Borough']=b
df['Neighborhood']=n
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# #### Let's clean our data!
# We only need the cells that have an assigned borough. Therefore, we can ignore the cells with a borough that is 'Not assigned'.
#
# In order to do that let's filter our data where the Borough is not equal to 'Not assigned':

# %%
ng_tnt=df[df['Borough'] != 'Not assigned'].reset_index(drop=True)

# %% [markdown]
# More than one neighborhood can exist in one postal code area. Luckly, the data frame that was extracted from Wikipedia came in that sort of way. So it is only necessary to check if the Postal Code are grouped correctly. Therefore, if the shape of the unique values of the Borough column is the same as the original, we can assume it is correct.

# %%
ng_tnt['Postal Code'].unique().shape[0]==ng_tnt['Postal Code'].shape[0]
# Out:
# True

# %% [markdown]
# #### Great! Now let's confirme that any neighborhood has 'Not assigned' values:

# %%
ng_tnt[ng_tnt['Neighborhood'] == 'Not assigned'].shape[0]
# Out:
# 0

# %% [markdown]
# And get the shape of the grouped data frame:

# %%
ng_tnt.shape
# Out:
# (103, 3)

# %% [markdown]
# ## *Uploading data frame with latitude and longitude information*

# %% [markdown]
# #### I tried to get the latitude and longitude of each postal code area by using geocoder, but I failed.
# > ## It was taking to long!
#
# *This is what I did...*

# %% [markdown]
# ```python
# !pip install geocoder
# import geocoder
#
#     def get_lat_log(postal):
#         lat_lng_coords = None
#         while(lat_lng_coords is None):
#           g = geocoder.google('{}, Toronto, Ontario'.format(postal))
#           lat_lng_coords = g.latlng
#
#         lat = lat_lng_coords[0]
#         long = lat_lng_coords[1]
#         return (lat, long)
#
#     lat_list=[]
#     long_list=[]
#
#     lat,long = get_lat_log(ng_group['Postal Code'][0])
#
#
# for pc in ng_group['Postal Code']:
#     (lat,long)=get_lat_log(pc)
#     lat_list.append(lat)
#     long_list.append(long)
#
# ng_group['Latitude']=lat_list
# ng_group['Longitude']=long_list
# ```

# %% [markdown]
# #### So, I decided to read the csv file and merge the latitude and longitude with my data frame:

# %%
df_ltlg=pd.read_csv('https://cocl.us/Geospatial_data')
df_ltlg.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
ng_data=ng_tnt.merge(df_ltlg, on='Postal Code', how='left')
ng_data
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# Let's check if the coordinates matches with Capstone example:

# %%
check=ng_data[ng_data['Postal Code'] =='M9V'].reset_index(drop=True)
check
# Out:
#   Postal Code    Borough                                       Neighborhood  \
# 0         M9V  Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
#
#     Latitude  Longitude
# 0  43.739416 -79.588437

# %% [markdown]
# It does! So, now we are ready to analyze our data and cluster it for a better visualization.

# %% [markdown]
# ## *Preparing data for clustering*
#
# For ease of analysis we consider only boroughs with the 'Toronto' word in it.

# %%
ng_data = ng_data[ng_data['Borough'].str.contains('Toronto')].reset_index(drop=True)
print(ng_data.shape)
ng_data.head()
# Out:
# (39, 5)
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %% [markdown]
# Plotting data without clusters for further analysis.

# %%
address = 'Toronto, ON'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
for lat, lng, label in zip(ng_data['Latitude'], ng_data['Longitude'], ng_data['Borough']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '10VW5NMQI1LHJF3ZDFKOBJKNJ1XNUT1WUS2HWWC1KNYZOUYX'
CLIENT_SECRET = 'SLHNFIPFSKJQTJAY0NVY3QXBRSXV4CNAK02U350DRRQ5IFEW'
VERSION = '20180605'

# %% [markdown]
# #### Let's create a function that loops through our neighborhood data and get the top venues
#
# Notice that we are setting a default value of 500 for our radius and a limit for the top 100 venues.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500,limit=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):    
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough', 
                  'Borough Latitude', 
                  'Borough Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    print('done')
    return(nearby_venues)

# %% [markdown]
# Now we apply it on our Borough data

# %%
toronto_venues = getNearbyVenues(names=ng_data['Borough'],
                                   latitudes=ng_data['Latitude'],
                                   longitudes=ng_data['Longitude']
                                  )
# Out:
# done

# %% [markdown]
# And examine the dataframe size

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1614, 7)
#             Borough  Borough Latitude  Borough Longitude  \
# 0  Downtown Toronto          43.65426         -79.360636
# 1  Downtown Toronto          43.65426         -79.360636
# 2  Downtown Toronto          43.65426         -79.360636
# 3  Downtown Toronto          43.65426         -79.360636
# 4  Downtown Toronto          43.65426         -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2      Morning Glory Cafe       43.653947       -79.361149
# 3  Cooper Koo Family YMCA       43.653249       -79.358008
# 4     Body Blitz Spa East       43.654735       -79.359874
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2       Breakfast Spot
# 3  Distribution Center
# 4                  Spa

# %% [markdown]
# ## *Analyze each Borough*

# %% [markdown]
# #### One Hot Encoding and grouping by city analyzed by its mean, to consider the frequency of each element

# %%
t1hot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
t1hot['Borough'] = toronto_venues['Borough'] 
t1hot = t1hot[[t1hot.columns[-1]] + list(t1hot.columns[:-1])]
tgb=t1hot.groupby('Borough').mean().reset_index()
print(tgb.shape)
tgb.head()
# Out:
# (4, 242)
#             Borough  Afghan Restaurant   Airport  Airport Food Court  \
# 0   Central Toronto           0.000000  0.000000            0.000000
# 1  Downtown Toronto           0.000817  0.000817            0.000817
# 2      East Toronto           0.000000  0.000000            0.000000
# 3      West Toronto           0.000000  0.000000            0.000000
#
#    Airport Gate  Airport Lounge  Airport Service  Airport Terminal  \
# 0      0.000000        0.000000         0.000000          0.000000
# 1      0.000817        0.001634         0.002451          0.001634
# 2      0.000000        0.000000         0.000000          0.000000
# 3      0.000000        0.000000         0.000000          0.000000
#
#    American Restaurant  Antique Shop  ...     Trail  Train Station  \
# 0             0.009434      0.000000  ...  0.018868       0.000000
# 1             0.014706      0.001634  ...  0.000817       0.002451
# 2             0.024194      0.000000  ...  0.016129       0.000000
# 3             0.000000      0.006250  ...  0.000000       0.000000
#
#    Vegetarian / Vegan Restaurant  Video Game Store  Vietnamese Restaurant  \
# 0                       0.009434          0.000000               0.009434
# 1                       0.010621          0.001634               0.003268
# 2                       0.000000          0.000000               0.000000
# 3                       0.018750          0.000000               0.006250
#
#    Wine Bar  Wine Shop  Wings Joint  Women's Store  Yoga Studio
# 0  0.000000   0.000000     0.000000       0.000000     0.009434
# 1  0.005719   0.000817     0.001634       0.000817     0.005719
# 2  0.008065   0.000000     0.000000       0.000000     0.024194
# 3  0.006250   0.006250     0.000000       0.000000     0.012500
#
# [4 rows x 242 columns]

# %% [markdown]
# #### Now let's display the top 10 venues for each borough

# %% [markdown]
# First we define a function to get the top index of a series

# %%
def top_n_val(row, limit):
    row2sort = row.iloc[1:]
    row_sorted = row2sort.sort_values(ascending=False)
    
    return row_sorted.index.values[0:limit]

# %% [markdown]
# And it is created the data frame with top 10 venues printed by column

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']
columns = ['Borough']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

tgb_sorted = pd.DataFrame(columns=columns)
tgb_sorted['Borough'] = tgb['Borough']

for ind in np.arange(tgb.shape[0]):
    tgb_sorted.iloc[ind, 1:] = top_n_val(tgb.iloc[ind, :], num_top_venues)

tgb_sorted.head()
# Out:
#             Borough 1st Most Common Venue 2nd Most Common Venue  \
# 0   Central Toronto           Coffee Shop        Sandwich Place
# 1  Downtown Toronto           Coffee Shop                  Café
# 2      East Toronto      Greek Restaurant           Coffee Shop
# 3      West Toronto                  Café                   Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Café           Pizza Place                  Park
# 1            Restaurant                 Hotel   Japanese Restaurant
# 2                  Café    Italian Restaurant               Brewery
# 3           Coffee Shop    Italian Restaurant                Bakery
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0      Sushi Restaurant                   Pub            Restaurant
# 1    Italian Restaurant                Bakery                  Park
# 2        Ice Cream Shop                  Park            Restaurant
# 3            Restaurant           Pizza Place        Breakfast Spot
#
#   9th Most Common Venue 10th Most Common Venue
# 0          Dessert Shop     Italian Restaurant
# 1                   Gym     Seafood Restaurant
# 2           Yoga Studio     Light Rail Station
# 3             Gift Shop                   Park

# %% [markdown]
# ## *Cluster Neighborhoods*

# %% [markdown]
# Run k-means to cluster the neighborhood into 4 clusters.

# %%
kclusters = 4
X = tgb.drop('Borough', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(X)
kmeans.labels_[0:10]
# Out:
# array([0, 3, 1, 2])

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
tgb_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
tnb_merged = ng_data
tnb_merged = tnb_merged.join(tgb_sorted.set_index('Borough'), on='Borough')
print(tnb_merged.shape)
tnb_merged.head()
# Out:
# (39, 16)
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               3           Coffee Shop
# 1  43.662301 -79.389494               3           Coffee Shop
# 2  43.657162 -79.378937               3           Coffee Shop
# 3  43.651494 -79.375418               3           Coffee Shop
# 4  43.676357 -79.293031               1      Greek Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café            Restaurant                 Hotel
# 1                  Café            Restaurant                 Hotel
# 2                  Café            Restaurant                 Hotel
# 3                  Café            Restaurant                 Hotel
# 4           Coffee Shop                  Café    Italian Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Japanese Restaurant    Italian Restaurant                Bakery
# 1   Japanese Restaurant    Italian Restaurant                Bakery
# 2   Japanese Restaurant    Italian Restaurant                Bakery
# 3   Japanese Restaurant    Italian Restaurant                Bakery
# 4               Brewery        Ice Cream Shop                  Park
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                  Park                   Gym     Seafood Restaurant
# 1                  Park                   Gym     Seafood Restaurant
# 2                  Park                   Gym     Seafood Restaurant
# 3                  Park                   Gym     Seafood Restaurant
# 4            Restaurant           Yoga Studio     Light Rail Station

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(tnb_merged['Latitude'], tnb_merged['Longitude'], tnb_merged['Neighborhood'], tnb_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## *Examine Clusters*

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# #### Cluster 1

# %%
c1=tnb_merged[tnb_merged['Cluster Labels'] ==0]
print(c1.shape)
c1.head()
# Out:
# (9, 16)
#    Postal Code          Borough  \
# 18         M4N  Central Toronto
# 19         M5N  Central Toronto
# 20         M4P  Central Toronto
# 21         M5P  Central Toronto
# 23         M4R  Central Toronto
#
#                                        Neighborhood   Latitude  Longitude  \
# 18                                    Lawrence Park  43.728020 -79.388790
# 19                                         Roselawn  43.711695 -79.416936
# 20                                 Davisville North  43.712751 -79.390197
# 21  Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 23               North Toronto West,  Lawrence Park  43.715383 -79.405678
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 18               0           Coffee Shop        Sandwich Place
# 19               0           Coffee Shop        Sandwich Place
# 20               0           Coffee Shop        Sandwich Place
# 21               0           Coffee Shop        Sandwich Place
# 23               0           Coffee Shop        Sandwich Place
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18                  Café           Pizza Place                  Park
# 19                  Café           Pizza Place                  Park
# 20                  Café           Pizza Place                  Park
# 21                  Café           Pizza Place                  Park
# 23                  Café           Pizza Place                  Park
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18      Sushi Restaurant                   Pub            Restaurant
# 19      Sushi Restaurant                   Pub            Restaurant
# 20      Sushi Restaurant                   Pub            Restaurant
# 21      Sushi Restaurant                   Pub            Restaurant
# 23      Sushi Restaurant                   Pub            Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 18          Dessert Shop     Italian Restaurant
# 19          Dessert Shop     Italian Restaurant
# 20          Dessert Shop     Italian Restaurant
# 21          Dessert Shop     Italian Restaurant
# 23          Dessert Shop     Italian Restaurant

# %% [markdown]
# ## Cluster 2

# %%
c2=tnb_merged[tnb_merged['Cluster Labels']==1]
print(c2.shape)
c2.head()
# Out:
# (5, 16)
#    Postal Code       Borough  \
# 4          M4E  East Toronto
# 12         M4K  East Toronto
# 15         M4L  East Toronto
# 17         M4M  East Toronto
# 38         M7Y  East Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 4                                         The Beaches  43.676357 -79.293031
# 12                       The Danforth West, Riverdale  43.679557 -79.352188
# 15                     India Bazaar, The Beaches West  43.668999 -79.315572
# 17                                    Studio District  43.659526 -79.340923
# 38  Business reply mail Processing Centre, South C...  43.662744 -79.321558
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 4                1      Greek Restaurant           Coffee Shop
# 12               1      Greek Restaurant           Coffee Shop
# 15               1      Greek Restaurant           Coffee Shop
# 17               1      Greek Restaurant           Coffee Shop
# 38               1      Greek Restaurant           Coffee Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 4                   Café    Italian Restaurant               Brewery
# 12                  Café    Italian Restaurant               Brewery
# 15                  Café    Italian Restaurant               Brewery
# 17                  Café    Italian Restaurant               Brewery
# 38                  Café    Italian Restaurant               Brewery
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 4         Ice Cream Shop                  Park            Restaurant
# 12        Ice Cream Shop                  Park            Restaurant
# 15        Ice Cream Shop                  Park            Restaurant
# 17        Ice Cream Shop                  Park            Restaurant
# 38        Ice Cream Shop                  Park            Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 4            Yoga Studio     Light Rail Station
# 12           Yoga Studio     Light Rail Station
# 15           Yoga Studio     Light Rail Station
# 17           Yoga Studio     Light Rail Station
# 38           Yoga Studio     Light Rail Station

# %% [markdown]
# ## Cluster 3

# %%
c3=tnb_merged[tnb_merged['Cluster Labels']==2]
print(c3.shape)
c3.head()
# Out:
# (6, 16)
#    Postal Code       Borough                                  Neighborhood  \
# 9          M6H  West Toronto                  Dufferin, Dovercourt Village
# 11         M6J  West Toronto                      Little Portugal, Trinity
# 14         M6K  West Toronto  Brockton, Parkdale Village, Exhibition Place
# 22         M6P  West Toronto                 High Park, The Junction South
# 25         M6R  West Toronto                        Parkdale, Roncesvalles
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 9   43.669005 -79.442259               2                  Café
# 11  43.647927 -79.419750               2                  Café
# 14  43.636847 -79.428191               2                  Café
# 22  43.661608 -79.464763               2                  Café
# 25  43.648960 -79.456325               2                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 9                    Bar           Coffee Shop    Italian Restaurant
# 11                   Bar           Coffee Shop    Italian Restaurant
# 14                   Bar           Coffee Shop    Italian Restaurant
# 22                   Bar           Coffee Shop    Italian Restaurant
# 25                   Bar           Coffee Shop    Italian Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 9                 Bakery            Restaurant           Pizza Place
# 11                Bakery            Restaurant           Pizza Place
# 14                Bakery            Restaurant           Pizza Place
# 22                Bakery            Restaurant           Pizza Place
# 25                Bakery            Restaurant           Pizza Place
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 9         Breakfast Spot             Gift Shop                   Park
# 11        Breakfast Spot             Gift Shop                   Park
# 14        Breakfast Spot             Gift Shop                   Park
# 22        Breakfast Spot             Gift Shop                   Park
# 25        Breakfast Spot             Gift Shop                   Park

# %% [markdown]
# ## Cluster 4

# %%
c4=tnb_merged[tnb_merged['Cluster Labels']==3]
print(c4.shape)
c4.head()
# Out:
# (19, 16)
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 5         M5E  Downtown Toronto                                  Berczy Park
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               3           Coffee Shop
# 1  43.662301 -79.389494               3           Coffee Shop
# 2  43.657162 -79.378937               3           Coffee Shop
# 3  43.651494 -79.375418               3           Coffee Shop
# 5  43.644771 -79.373306               3           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café            Restaurant                 Hotel
# 1                  Café            Restaurant                 Hotel
# 2                  Café            Restaurant                 Hotel
# 3                  Café            Restaurant                 Hotel
# 5                  Café            Restaurant                 Hotel
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Japanese Restaurant    Italian Restaurant                Bakery
# 1   Japanese Restaurant    Italian Restaurant                Bakery
# 2   Japanese Restaurant    Italian Restaurant                Bakery
# 3   Japanese Restaurant    Italian Restaurant                Bakery
# 5   Japanese Restaurant    Italian Restaurant                Bakery
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                  Park                   Gym     Seafood Restaurant
# 1                  Park                   Gym     Seafood Restaurant
# 2                  Park                   Gym     Seafood Restaurant
# 3                  Park                   Gym     Seafood Restaurant
# 5                  Park                   Gym     Seafood Restaurant
